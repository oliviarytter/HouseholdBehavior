# %% [markdown]
# # Assignment 1

# %% [markdown]
# 1. What value of $β_1$ produces an event-study graph of working hours with something close
# to a drop in hours of 10pct around the time of birth as in Kleven, Landais and Søgaard
# (2019, Fig. 1B)? Be explicit about how you found the value.

# %% [markdown]
# 2. Introduce in the model a spouse who contributes with income $y_t$ every period. Let the
# income depend on age/period, such that $y_t = 0.1+0.01·t$. Write out the a ected equations
# and implement it in Python. Compare and comment on the simulated behavior
# from this alternative model in relation to that of the baseline model above. Concretely
# plot age pro les of e.g. labor supply, consumption, fertility and savings.
# $[y_t = 0∀t$ gives the baseline model.]

# %% [markdown]
# 3. Introduce in the model a childcare cost of $θ = 0.05$ in the presence of a child. You
# can think of this as a policy reform reducing the child care subsidy. Write out the
# a ected equations and implement it in Python. Compare the simulated behavior from this alternative model in relation to that of the baseline model above. Compare also the Marshall elasticity in both models and comment on how the income and substitution
# effects differs (you do not need to calculate them). [$y_t = 0∀t$ and $θ = 0$ gives the baseline model.]

# %% [markdown]
# 4. Discuss how endogenous fertility adjustments could a ect the impact of a child subsidy
# reform as the one above. Specifically, think about substitution and income effects
# related to fertility.

# %% [markdown]
# 5. Imagine that whether an income-generating spouse is present or not is random and $p_s =
# 0.8$ is the likelihood that a spouse is present in a given period. Furthermore, imagine
# that a child can only arrive next period if a spouse is currently present. Formulate
# mathematically the recursive formulation of this model and implement it in Python.
# Compare the simulated behavior from this alternative model in relation to that of the
# baseline model above.
# [$y_t = 0∀t, θ = 0$ and $p_s = 1$ gives the baseline model.]
